# %%
from ratinabox.Environment import Environment
from ratinabox.Agent import Agent
import matplotlib.pyplot as plt
import numpy as np
from rat_gym import RatGym

# %%
env = RatGym()
env.add_wall([np.array([0.2, 0.2]), np.array([0.2, 0.8])])
env.add_wall([np.array([0.8, 0.2]), np.array([0.8, 0.8])])
obs = env.reset()

# %%
act = np.array([1, 0])
obs, reward, done, info = env.step(act)
plt.imshow(obs.reshape(100, 100, 3))
